# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os

# %cd /content/gdrive/MyDrive/DCD_2022/음식 이미지 및 영양정보 텍스트/train_sampling/갈치조림


for i in os.listdir():
  os.rename(i, i[:46])
# Out:
# /content/gdrive/.shortcut-targets-by-id/1wOrLfCRYDKybRCZZTfYwGsFSjYkPkBYf/DCD_2022/음식 이미지 및 영양정보 텍스트/train_sampling/갈치조림

# %%
ls
# Out:
# 'side_생선조림_냄비_갈치조림_Q1 00002.JPG'
# 'side_생선조림_냄비_갈치조림_Q1 00003.JPG'
# 'side_생선조림_냄비_갈치조림_Q1 00004.JPG'
# 'side_생선조림_냄비_갈치조림_Q1 00005.JPG'
# 'side_생선조림_냄비_갈치조림_Q1 00006.JPG'
# 'side_생선조림_냄비_갈치조림_Q1 00007.JPG'
# 'side_생선조림_냄비_갈치조림_Q1 00008.JPG'
# 'side_생선조림_냄비_갈치조림_Q1 00009.JPG'
# 'side_생선조림_냄비_갈치조림_Q1 00010.JPG'
# 'side_생선조림_냄비_갈치조림_Q1 00011.JPG'
# 'side_생선조림_냄비_갈치조림_Q2 00047.JPG'
# 'side_생선조림_냄비_갈치조림_Q2 00048.JPG'
# 'side_생선조림_냄비_갈치조림_Q2 00049.JPG'
# 'side_생선조림_냄비_갈치조림_Q2 00050.JPG'
# 'side_생선조림_냄비_갈치조림_Q2 00051.JPG'
# 'side_생선조림_냄비_갈치조림_Q2 00052.JPG'
# 'side_생선조림_냄비_갈치조림_Q2 00053.JPG'
# 'side_생선조림_냄비_갈치조림_Q3 00001.JPG'
# 'side_생선조림_냄비_갈치조림_Q3 00002.JPG'
# ...
